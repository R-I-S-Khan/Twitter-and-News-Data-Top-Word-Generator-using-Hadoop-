# %% [markdown]
# # Redwan Ibne Seraj Khan
# # Ubitname : rikhan
# # DATA AGGREGATION, BIG DATA ANALYSIS AND VISUALIZATION (PART 2)

# %%
library(twitteR)
setup_twitter_oauth("DmC9SmlXZSTVHUZHlsEOriOHK","arSDUCTSBBkgz2QT3WslMKmIo2wK8IcXvSPVRK35Yn73YXBUpZ",
"912551396184068096-uTzNTAY36ozI0Gq1x10dq84mUpDAyLm","mKlpTAcT9daHWTGFtiGeD9PpAOIgYDhEwXwQZG4M0XNCm")
# Out:
# Warning message:
# "package 'twitteR' was built under R version 3.4.3"
# [1] "Using direct authentication"

# %%
item_search <- readline(prompt="Enter an item to search: ")

search = searchTwitter(item_search, n = 8000) #items_searched = #trump
# Out:
# Enter an item to search: #TrumpsArmy

# %%
search_df = twListToDF(search)
write.csv(search_df, file = "D:/Spring 2018/CSE 487/R files/trump3.csv",row.names = FALSE, na = "")

# %%
head(search_df)
# Out:
#   text
# 1 RT @Jamierodr10: Join the Movement <U+201C>Fight Sanctuary State<U+201D>! They want to repeal Sanctuary Laws!!  As Proud Americans we need to look into t<U+2026>
# 2 RT @Jamierodr10: GOOD MORNING PATRIOTS <ed><U+00A0><U+00BC><ed><U+00B7><U+00BA><ed><U+00A0><U+00BC><ed><U+00B7><U+00B8><ed><U+00A0><U+00BC><ed><U+00B7><U+00BA><ed><U+00A0><U+00BC><ed><U+00B7><U+00B8>.         THE STRONGEST WEAPON IN THE UNITED STATES IS A PATRIOTIC AMERICAN! Raise your #Voice a<U+2026>
# 3 RT @Jamierodr10: It<U+2019>s #Disqusting to hear the Left always attacking our #Amazing First Lady! She is Full of #Grace and #Beauty! It<U+2019>s time t<U+2026>
# 4 RT @Jamierodr10: It<U+2019>s #Disqusting to hear the Left always attacking our #Amazing First Lady! She is Full of #Grace and #Beauty! It<U+2019>s time t<U+2026>
# 5 RT @AnnaApp91838450: @TrumpTrainMRA4 @POTUS @realDonaldTrump CORRUPT LYING DEMOCRATS\nNEED TO GIVE UP<ed><U+00A0><U+00BD><ed><U+00B2><U+00A5>63 + MILLION MIGHT I ADD "GROWING " KN<U+2026>
# 6 RT @Jamierodr10: Join the Movement <U+201C>Fight Sanctuary State<U+201D>! They want to repeal Sanctuary Laws!!  As Proud Americans we need to look into t<U+2026>
#   favorited favoriteCount replyToSN created             truncated replyToSID
# 1 FALSE     0             NA        2018-04-04 19:06:45 FALSE     NA
# 2 FALSE     0             NA        2018-04-04 19:06:39 FALSE     NA
# 3 FALSE     0             NA        2018-04-04 19:06:35 FALSE     NA
# 4 FALSE     0             NA        2018-04-04 19:06:33 FALSE     NA
# 5 FALSE     0             NA        2018-04-04 19:06:22 FALSE     NA
# 6 FALSE     0             NA        2018-04-04 19:06:20 FALSE     NA
#   id                 replyToUID
# 1 981609032132845569 NA
# 2 981609008032309248 NA
# 3 981608989606797313 NA
# 4 981608982963015682 NA
# 5 981608938339618816 NA
# 6 981608925920407552 NA
#   statusSource
# 1 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 2 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 3 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4 <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 5 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 6 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
#   screenName      retweetCount isRetweet retweeted longitude latitude
# 1 DrFred57         19          TRUE      FALSE     NA        NA
# 2 Julianwhiterid2 310          TRUE      FALSE     NA        NA
# 3 debmille        403          TRUE      FALSE     NA        NA
# 4 joshey_pants    403          TRUE      FALSE     NA        NA
# 5 l_jlhenry77      30          TRUE      FALSE     NA        NA
# 6 zxdcvasdf        18          TRUE      FALSE     NA        NA

# %%
head(search_df$text)
# Out:
# [1] "RT @Jamierodr10: Join the Movement <U+201C>Fight Sanctuary State<U+201D>! They want to repeal Sanctuary Laws!!  As Proud Americans we need to look into t<U+2026>"
# [2] "RT @Jamierodr10: GOOD MORNING PATRIOTS <ed><U+00A0><U+00BC><ed><U+00B7><U+00BA><ed><U+00A0><U+00BC><ed><U+00B7><U+00B8><ed><U+00A0><U+00BC><ed><U+00B7><U+00BA><ed><U+00A0><U+00BC><ed><U+00B7><U+00B8>.         THE STRONGEST WEAPON IN THE UNITED STATES IS A PATRIOTIC AMERICAN! Raise your #Voice a<U+2026>"
# [3] "RT @Jamierodr10: It<U+2019>s #Disqusting to hear the Left always attacking our #Amazing First Lady! She is Full of #Grace and #Beauty! It<U+2019>s time t<U+2026>"
# [4] "RT @Jamierodr10: It<U+2019>s #Disqusting to hear the Left always attacking our #Amazing First Lady! She is Full of #Grace and #Beauty! It<U+2019>s time t<U+2026>"
# [5] "RT @AnnaApp91838450: @TrumpTrainMRA4 @POTUS @realDonaldTrump CORRUPT LYING DEMOCRATS\nNEED TO GIVE UP<ed><U+00A0><U+00BD><ed><U+00B2><U+00A5>63 + MILLION MIGHT I ADD \"GROWING \" KN<U+2026>"
# [6] "RT @Jamierodr10: Join the Movement <U+201C>Fight Sanctuary State<U+201D>! They want to repeal Sanctuary Laws!!  As Proud Americans we need to look into t<U+2026>"

# %%
Sys.setlocale('LC_ALL','C') #resolving the encoding problem while converting to dataframe

search_df <- twListToDF(search)   #conversion to dataframe
head(search_df)

head(search_df$text)

write(search_df$text, file = "trump_tweets3.txt", append = FALSE, sep = "\n")
# Out:
# [1] "C"
#   text
# 1 RT @Jamierodr10: Join the Movement <U+201C>Fight Sanctuary State<U+201D>! They want to repeal Sanctuary Laws!!  As Proud Americans we need to look into t<U+2026>
# 2 RT @Jamierodr10: GOOD MORNING PATRIOTS <ed><U+00A0><U+00BC><ed><U+00B7><U+00BA><ed><U+00A0><U+00BC><ed><U+00B7><U+00B8><ed><U+00A0><U+00BC><ed><U+00B7><U+00BA><ed><U+00A0><U+00BC><ed><U+00B7><U+00B8>.         THE STRONGEST WEAPON IN THE UNITED STATES IS A PATRIOTIC AMERICAN! Raise your #Voice a<U+2026>
# 3 RT @Jamierodr10: It<U+2019>s #Disqusting to hear the Left always attacking our #Amazing First Lady! She is Full of #Grace and #Beauty! It<U+2019>s time t<U+2026>
# 4 RT @Jamierodr10: It<U+2019>s #Disqusting to hear the Left always attacking our #Amazing First Lady! She is Full of #Grace and #Beauty! It<U+2019>s time t<U+2026>
# 5 RT @AnnaApp91838450: @TrumpTrainMRA4 @POTUS @realDonaldTrump CORRUPT LYING DEMOCRATS\nNEED TO GIVE UP<ed><U+00A0><U+00BD><ed><U+00B2><U+00A5>63 + MILLION MIGHT I ADD "GROWING " KN<U+2026>
# 6 RT @Jamierodr10: Join the Movement <U+201C>Fight Sanctuary State<U+201D>! They want to repeal Sanctuary Laws!!  As Proud Americans we need to look into t<U+2026>
#   favorited favoriteCount replyToSN created             truncated replyToSID
# 1 FALSE     0             NA        2018-04-04 19:06:45 FALSE     NA
# 2 FALSE     0             NA        2018-04-04 19:06:39 FALSE     NA
# 3 FALSE     0             NA        2018-04-04 19:06:35 FALSE     NA
# 4 FALSE     0             NA        2018-04-04 19:06:33 FALSE     NA
# 5 FALSE     0             NA        2018-04-04 19:06:22 FALSE     NA
# 6 FALSE     0             NA        2018-04-04 19:06:20 FALSE     NA
#   id                 replyToUID
# 1 981609032132845569 NA
# 2 981609008032309248 NA
# 3 981608989606797313 NA
# 4 981608982963015682 NA
# 5 981608938339618816 NA
# 6 981608925920407552 NA
#   statusSource
# 1 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 2 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 3 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4 <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 5 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 6 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
#   screenName      retweetCount isRetweet retweeted longitude latitude
# 1 DrFred57         19          TRUE      FALSE     NA        NA
# 2 Julianwhiterid2 310          TRUE      FALSE     NA        NA
# 3 debmille        403          TRUE      FALSE     NA        NA
# 4 joshey_pants    403          TRUE      FALSE     NA        NA
# 5 l_jlhenry77      30          TRUE      FALSE     NA        NA
# 6 zxdcvasdf        18          TRUE      FALSE     NA        NA
# [1] "RT @Jamierodr10: Join the Movement <U+201C>Fight Sanctuary State<U+201D>! They want to repeal Sanctuary Laws!!  As Proud Americans we need to look into t<U+2026>"
# [2] "RT @Jamierodr10: GOOD MORNING PATRIOTS <ed><U+00A0><U+00BC><ed><U+00B7><U+00BA><ed><U+00A0><U+00BC><ed><U+00B7><U+00B8><ed><U+00A0><U+00BC><ed><U+00B7><U+00BA><ed><U+00A0><U+00BC><ed><U+00B7><U+00B8>.         THE STRONGEST WEAPON IN THE UNITED STATES IS A PATRIOTIC AMERICAN! Raise your #Voice a<U+2026>"
# [3] "RT @Jamierodr10: It<U+2019>s #Disqusting to hear the Left always attacking our #Amazing First Lady! She is Full of #Grace and #Beauty! It<U+2019>s time t<U+2026>"
# [4] "RT @Jamierodr10: It<U+2019>s #Disqusting to hear the Left always attacking our #Amazing First Lady! She is Full of #Grace and #Beauty! It<U+2019>s time t<U+2026>"
# [5] "RT @AnnaApp91838450: @TrumpTrainMRA4 @POTUS @realDonaldTrump CORRUPT LYING DEMOCRATS\nNEED TO GIVE UP<ed><U+00A0><U+00BD><ed><U+00B2><U+00A5>63 + MILLION MIGHT I ADD \"GROWING \" KN<U+2026>"
# [6] "RT @Jamierodr10: Join the Movement <U+201C>Fight Sanctuary State<U+201D>! They want to repeal Sanctuary Laws!!  As Proud Americans we need to look into t<U+2026>"

# %%
mapreduced <- read.csv("mapreduced2.csv",sep=",")

head(mapreduced)
# Out:
#   X.             X3
# 1 ##senate       3
# 2 #1a            2
# 3 #1linewed      1
# 4 #1u            1
# 5 #2016abdbaimi  1
# 6 #2016election. 1

# %%
mapreduced <- setNames(mapreduced,  c("Tag","Freq"))
head(mapreduced)
# Out:
#   Tag            Freq
# 1 ##senate       3
# 2 #1a            2
# 3 #1linewed      1
# 4 #1u            1
# 5 #2016abdbaimi  1
# 6 #2016election. 1

# %%
unicodeSubsetData <- mapreduced[ grep("<u+", mapreduced$Tag), ]
unicodeSubsetData <- unicodeSubsetData[ grep("<U+", unicodeSubsetData$Tag)]

# %%
mapreduced_new <- setdiff(mapreduced,unicodeSubsetData)  # the new df has most unicode values removed to produce a clear tag cloud

# %%
# source: http://www.sthda.com/english/wiki/text-mining-and-word-cloud-fundamentals-in-r-5-simple-steps-you-should-know#step-1-create-a-text-file

mapreduced_new <- na.omit(mapreduced_new)

library('wordcloud')
library('RColorBrewer')

# %%
set.seed(1234)
wordcloud(words = mapreduced_new$Tag, freq = mapreduced_new$Freq, min.freq = 2,
          max.words=200, random.order=FALSE, rot.per=0.35, 
          colors=brewer.pal(8, "Dark2"))
# Out:
# plot without title

# %%
NewsDataMapReduced <- read.csv("NewsDataMapReduced.csv",sep=",")

head(NewsDataMapReduced)
# Out:
#   X.1........part           X1
# 1 During\t1\nI               1
# 2 Kompromat                 1
# 3 Mr.\t1\nbeautiful,         1
# 4 blow\t1\nbot"              1
# 5 branded                   1
# 6 burdensome\t1\ncultivated" 1

# %%
NewsDataMapReduced <- setNames(NewsDataMapReduced,  c("Tag","Freq"))
head(NewsDataMapReduced)
# Out:
#   Tag                       Freq
# 1 During\t1\nI               1
# 2 Kompromat                 1
# 3 Mr.\t1\nbeautiful,         1
# 4 blow\t1\nbot"              1
# 5 branded                   1
# 6 burdensome\t1\ncultivated" 1

# %%
unicodeSubsetData <- NewsDataMapReduced[ grep("<u+", NewsDataMapReduced$Tag), ]
head(unicodeSubsetData)
# Out:
#      Tag Freq

# %%
NewsDataMapReduced_new <- setdiff(NewsDataMapReduced,unicodeSubsetData)  # for producing a clear tag most unicode values have been removed

# %%
NewsDataMapReduced_new <- na.omit(NewsDataMapReduced_new)

library('wordcloud')
library('RColorBrewer')

# %%
set.seed(1234)
wordcloud(words = NewsDataMapReduced_new$Tag, freq = NewsDataMapReduced_new$Freq, min.freq = 1,
          max.words=200, random.order=FALSE, rot.per=0.35, 
          colors=brewer.pal(8, "Dark2"))
# Out:
# plot without title

# %%
Pairsdata = read.csv("PairCooccur1.csv")

# %%
Pairsdata
# Out:
#       Pairs                      Count
# 1     AB,2026                    1
# 2     AB,3swNxVhIJF              1
# 3     AB,U                       1
# 4     AB,co                      1
# 5     AB,https                   1
# 6     AB,t                       1
# 7     ABC,2026                   2
# 8     ABC,2wE1GABNQH             2
# 9     ABC,Best                   2
# 10    ABC,I                      2
# 11    ABC,IS                     2
# 12    ABC,In                     2
# 13    ABC,Love                   2
# 14    ABC,POTUS                  2
# 15    ABC,President              2
# 16    ABC,The                    2
# 17    ABC,U                      2
# 18    ABC,co                     2
# 19    ABC,https                  2
# 20    ABC,lifetime               2
# 21    ABC,our                    4
# 22    ABC,realDonaldTrump        2
# 23    ABC,t                      2
# 24    ABI,2018                   1
# 25    ABI,23                     1
# 26    ABI,FEB                    1
# 27    ABI,HABIB                  2
# 28    ABI,KAI                    1
# 29    ABI,abi                    2
# 30    ABI,by                     2
# ...   ...                        ...
# 71873 ze,U                         6
# 71874 zero,evidence                1
# 71875 zitoxicboy,0082              8
# 71876 zitoxicboy,0085              8
# 71877 zitoxicboy,00A0             24
# 71878 zitoxicboy,00A3              8
# 71879 zitoxicboy,00B4              8
# 71880 zitoxicboy,00B8             16
# 71881 zitoxicboy,00BD             16
# 71882 zitoxicboy,00BE              8
# 71883 zitoxicboy,2026              8
# 71884 zitoxicboy,Fantasy           8
# 71885 zitoxicboy,Impe              8
# 71886 zitoxicboy,Patel             8
# 71887 zitoxicboy,ShafPatel         8
# 71888 zitoxicboy,TrumpsArmy        8
# 71889 zitoxicboy,U               104
# 71890 zitoxicboy,a                 8
# 71891 zitoxicboy,ed               48
# 71892 zitoxicboy,good              8
# 71893 zitoxicboy,he                8
# 71894 zitoxicboy,laugh             8
# 71895 zitoxicboy,luck              8
# 71896 zitoxicboy,on                8
# 71897 zitoxicboy,pushing           8
# 71898 zitoxicboy,realDonaldTrump   8
# 71899 zitoxicboy,thinks            8
# 71900 zitoxicboy,understands       8
# 71901 zitoxicboy,what              8
# 71902 zitoxicboy,your              8

# %%
Pairstop = subset (Pairsdata, Pairsdata$Count > 19000, select=c (Pairs,Count))

# %%
Pairstop
# Out:
#       Pairs            Count
# 17493 PATRIOTS,U       27476
# 38470 Trump,rich       52438
# 38481 Republican,vote  19032
# 38484 Trumparmy,strong 21598
# 38489 Son,palace       30306
# 38490 Ivanka,goddess   19316
# 38494 Trumpa,eagle     27454
# 38495 Trumped,Hilary   24259
# 38505 elect,trumpwin   20140
# 38868 trumped,joy      85148

# %%
Pairsdata2 = read.csv("PairCooccur2.csv")

# %%
Pairstop2 = subset (Pairsdata2, Pairsdata2$Count > 3000, select=c (Pair,Count))

# %%
Pairstop2
# Out:
#        Pair                   Count
# 607    Ability,FederalReserve 5007
# 2001   Amazon,tax             3400
# 77691  economy,announcing     5804
# 148464 world,dangerous        4509
# 148469 world,economy          5600
# 148684 would,2026             3457
# 149397 years,collecting       8290
# 149398 years,companies        5432
# 149478 years,taxes            3801
# 150100 young,imagination      6004
